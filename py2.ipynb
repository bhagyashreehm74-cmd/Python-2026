# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashreehm74-cmd/Python-2026/blob/main/py2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
   print("Even")
else:
   print("Odd")
# Out:
# Enter a number: 5
# Odd
